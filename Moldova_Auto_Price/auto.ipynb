# %%
import pandas as pd

# %%
df = pd.read_csv('file_2.csv')
df.head(28)
# Out:
#                        name                    group     price  country  \
# 0                  -SCars-     Легковые автомобили     23 999   Молдова
# 1                  TopAuto     Легковые автомобили      2 999   Молдова
# 2                  TopAuto     Легковые автомобили      5 999   Молдова
# 3            alexciornii17     Легковые автомобили     15 900   Молдова
# 4                caddy2006     Легковые автомобили      4 950   Молдова
# 5                 BOSBOS92     Легковые автомобили      8 900   Молдова
# 6                 78104444     Легковые автомобили      3 850   Молдова
# 7                      ddo     Легковые автомобили     29 500   Молдова
# 8                   nikbmw     Легковые автомобили     18 700   Молдова
# 9                 BOSBOS92     Легковые автомобили      6 600   Молдова
# 10                  MMM353     Легковые автомобили     58 900   Молдова
# 11                 Denis39     Легковые автомобили      8 600   Молдова
# ...
